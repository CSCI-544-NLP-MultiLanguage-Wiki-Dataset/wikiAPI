# %%
from googletrans import Translator
import pandas as pd
translator = Translator()

# %%
translator.translate('My name is divyam khanna', dest='tr').text
# Out:
# 'Maya adına Divyam Khanna mı'

# %%
en_data = pd.read_csv('wikiAPI/datasets/en_04_17.csv')

# %%
# %%time

translated_text = {}
for i, row in enumerate(en_data.text):
    try:
        translated_text[i] = translator.translate(row, dest='tr').text
    except Exception as e:
        print(e, i)
        continue
# Out:
# 'NoneType' object is not iterable 3221
# 'NoneType' object is not iterable 6728
# 'NoneType' object is not iterable 6769
# 'NoneType' object is not iterable 6771
# 'NoneType' object is not iterable 6814
# 'NoneType' object is not iterable 6826
# Wall time: 18min 26s

# %%
translated_text[3221] = """Euromoney dergisi her yıl Yılın Maliye Bakanı ödülünü veriyor. Geçmiş alıcılar aşağıda listelenmiştir.\r\n1981 Türkiye'den Turgut Özal\r\n1982 Singapur'dan Hon Sui Sen\r\n1983 Meksika'dan Jesús Silva Herzog\r\n1984 Avustralya'dan Paul Keating\r\n1985 Yeni Zelanda'dan Roger Douglas\ r\n1986 Amerika Birleşik Devletleri'nden James Baker\r\n1987 Fransa'dan Edouard Balladur\r\n88 Birleşik Krallık'tan Nigel Lawson\r\n1989 Endonezya'dan J. B. Sumarlin\r\n1990 Belçika'dan Philippe Maystadt\r\n1991 Carlos İspanya'dan Solchaga\r\n1992 Arjantin'den Domingo Cavallo\r\n1993 Hindistan'dan Manmohan Singh\r\n1994 Finlandiya'dan Iiro Viinanen\r\n1995 Filipinler'den Roberto de Ocampo\r\n1996 Amerika Birleşik Devletleri'nden Robert Rubin\r\n1994 r\n1997 Rusya'dan Anatoly Chubais\r\n1998 Polonya'dan Leszek Balcerowicz\r\n1999 Meksika'dan José Ángel Gurría\r\n2000 Slovakya'dan Brigita Schmögnerová\r\n2001 Pakistan'dan Shaukat Aziz\r\n2002 Bulgaristan'dan Milen Veltchev\r \n2003 Suudi Arabistan'dan İbrahim bin Abdülaziz Al-Assaf\r\n2004 Slovakya'dan Ivan Miklos\r\n2005 Nijerya'dan Ngozi Okonjo-Iweala\r\n2006 Sri Muly Endonezya'dan ani Indrawati\r\n2007 Sırbistan'dan Mlađan Dinkić\r\n2008 Çin'den Xie Xuren\r\n2009 Kanada'dan Jim Flaherty\r\n2010 Rusya'dan Alexei Kudrin\r\n2011 Avustralya'dan Wayne Swan\r\n2012 Cesar Purisima Filipinler\r\n2013 Singapurlu Tharman Shanmugaratnam\r\n2014 Meksikalı Luis Videgaray Caso\r\n2015 Kolombiyalı Mauricio Cárdenas Santamaría\r\n2016 Arjantinli Alfonso Prat-GayBu ödül halk dilinde "Dünyanın En Büyük Hazinedarı" olarak adlandırıldı Paul Keating 1984'te kazandıktan sonra Avustralya'da.\r\n\r\n\r\n== Referanslar =="""

# %%
translated_text[6826] = """Sukisho, Japonya'da Suki na Mono wa Suki Dakara Shōganai!! (好きなものは好きだからしょうがない!!, yanıyor. Sevdiğim Şeyi Seviyorum, So It Can't Be Helped!), UNISONSHIFT tarafından geliştirilen ve 10 Eylül 1999'da piyasaya sürülen bir Japon görsel romanıdır. Hafif roman serisine ve Zexcs tarafından canlandırılan ve Ocak-Mart 2005 arasında yayınlanan bir anime televizyon dizisine uyarlandı. Sürümlerin en iyi bilineni, hafif BL ve orijinal Windows sürümünde hardcore BL içeren görsel romandır. Hikaye SOFTPAL ve Platinum Label'a aittir ve roman ve oyunların illüstrasyonları Tsutae Yuzu'ya aittir."""

# %%
en_data
# Out:
#       Unnamed: 0    pageid                                   title  \
# 0              0     26700                                 Science
# 1              1   9145213                      Outline of science
# 2              2  70476313  Monochrome-astrophotography-techniques
# 3              3     26997                               Scientist
# 4              4   9145213                      Outline of science
# ...          ...       ...                                     ...
# 6995        6995  65326971                     Pop culture fiction
# 6996        6996     24145                                     Pun
# 6997        6997   1311322                             Satire boom
# 6998        6998   9765056                       Satirical ostraca
# 6999        6999   2405960                              Smelfungus
#
#            category  label language  \
# 0           Science      0       en
# 1           Science      0       en
# 2           Science      0       en
# ...

# %%
tlist = [(k, v) for k, v in translated_text.items()]

# %%
en_data['translated_text'] = [x[1] for x in sorted(tlist, key=lambda x: x[0])]

# %%
en_data
# Out:
#       Unnamed: 0    pageid                                   title  \
# 0              0     26700                                 Science
# 1              1   9145213                      Outline of science
# 2              2  70476313  Monochrome-astrophotography-techniques
# 3              3     26997                               Scientist
# 4              4   9145213                      Outline of science
# ...          ...       ...                                     ...
# 6995        6995  65326971                     Pop culture fiction
# 6996        6996     24145                                     Pun
# 6997        6997   1311322                             Satire boom
# 6998        6998   9765056                       Satirical ostraca
# 6999        6999   2405960                              Smelfungus
#
#            category  label language  \
# 0           Science      0       en
# 1           Science      0       en
# 2           Science      0       en
# ...

# %%
cats = {
    'Science': 'Bilim',
    'Sports':'Spor',
    'Economy':'Ekonomi',
    'Politics':'Siyaset',
    'Education':'Eğitim',
    'Health':'Sağlık',
    'Entertainment':'Eğlence'
}

# %%
en_data['translated_category'] = en_data['category'].map(cats)

# %%
en_data
# Out:
#       Unnamed: 0    pageid                                   title  \
# 0              0     26700                                 Science
# 1              1   9145213                      Outline of science
# 2              2  70476313  Monochrome-astrophotography-techniques
# 3              3     26997                               Scientist
# 4              4   9145213                      Outline of science
# ...          ...       ...                                     ...
# 6995        6995  65326971                     Pop culture fiction
# 6996        6996     24145                                     Pun
# 6997        6997   1311322                             Satire boom
# 6998        6998   9765056                       Satirical ostraca
# 6999        6999   2405960                              Smelfungus
#
#            category  label language  \
# 0           Science      0       en
# 1           Science      0       en
# 2           Science      0       en
# ...

# %%
en_data.to_csv("en_04_17_translated.csv")

# %%
tr_data = pd.read_csv('wikiAPI/datasets/tr_04_14.csv')

# %%
# %%time

translated_text_tr = {}
for i, row in enumerate(tr_data.text):
    try:
        translated_text_tr[i] = translator.translate(row, dest='en').text
    except Exception as e:
        print(e, i)
        continue
# Out:
# Wall time: 31min 33s

# %%
tlist = [(k, v) for k, v in translated_text_tr.items()]

# %%
tr_data['translated_text'] = [x[1] for x in sorted(tlist, key=lambda x: x[0])]

# %%
tr_data
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1   pageid              title  \
# 0              0           0.0             0.0     1047              Bilim
# 1              1           1.0             1.0  2809249      Felsefe-Bilim
# 2              2           2.0             2.0  2550334      Oktay Güvemli
# 3              3           3.0             3.0  2781041   Matematik tarihi
# 4              4           4.0             4.0  2966687    Terra incognita
# ...          ...           ...             ...      ...                ...
# 6995        6995           NaN             NaN  2889479          Azur Lane
# 6996        6996           NaN             NaN  2892883        Banana Fish
# 6997        6997           NaN             NaN   517230   Basilisk (manga)
# 6998        6998           NaN             NaN  2969195  Beelzebub (manga)
# 6999        6999           NaN             NaN  3209650          Big Order
#
#      category  label language  \
# 0       Bilim      0       tr
# ...

# %%
cat_tr = {v: k for k, v in cats.items()}
cat_tr
# Out:
# {'Bilim': 'Science',
#  'Spor': 'Sports',
#  'Ekonomi': 'Economy',
#  'Siyaset': 'Politics',
#  'Eğitim': 'Education',
#  'Sağlık': 'Health',
#  'Eğlence': 'Entertainment'}

# %%
tr_data['translated_category'] = tr_data['category'].map(cat_tr)

# %%
tr_data
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1   pageid              title  \
# 0              0           0.0             0.0     1047              Bilim
# 1              1           1.0             1.0  2809249      Felsefe-Bilim
# 2              2           2.0             2.0  2550334      Oktay Güvemli
# 3              3           3.0             3.0  2781041   Matematik tarihi
# 4              4           4.0             4.0  2966687    Terra incognita
# ...          ...           ...             ...      ...                ...
# 6995        6995           NaN             NaN  2889479          Azur Lane
# 6996        6996           NaN             NaN  2892883        Banana Fish
# 6997        6997           NaN             NaN   517230   Basilisk (manga)
# 6998        6998           NaN             NaN  2969195  Beelzebub (manga)
# 6999        6999           NaN             NaN  3209650          Big Order
#
#      category  label language  \
# 0       Bilim      0       tr
# ...

# %%
tr_data.to_csv('wikiAPI/datasets/tr_04_14_translated.csv')

# %%
tr_data
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1   pageid              title  \
# 0              0           0.0             0.0     1047              Bilim
# 1              1           1.0             1.0  2809249      Felsefe-Bilim
# 2              2           2.0             2.0  2550334      Oktay Güvemli
# 3              3           3.0             3.0  2781041   Matematik tarihi
# 4              4           4.0             4.0  2966687    Terra incognita
# ...          ...           ...             ...      ...                ...
# 6995        6995           NaN             NaN  2889479          Azur Lane
# 6996        6996           NaN             NaN  2892883        Banana Fish
# 6997        6997           NaN             NaN   517230   Basilisk (manga)
# 6998        6998           NaN             NaN  2969195  Beelzebub (manga)
# 6999        6999           NaN             NaN  3209650          Big Order
#
#      category  label language  \
# 0       Bilim      0       tr
# ...
